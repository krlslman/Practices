# %%
print("hello world") #print bir foksiyondur
                     #tırnak içindeki ifade string (sicim) olur
# Out:
# hello world

# %%
print( "çift tırnakla başladım çiftle bitirdim")  #tek tırnakla başladıysan tekle bitir, çiftse çift
# Out:
# çift tırnakla başladım çiftle bitirdim

# %%
print("""benim adın koral,
sporu ve disiplini severim,
sabah erken kalkarım""")  # üç kere çift ya da tek tırnak kullanarak çoklu satırları yazdırabilirsin
# Out:
# benim adın joseph,
# ben sizi çok sevdim,
# sizde huzur var

# %%
print(""" "neredesin?" "erzurum'dayım" """)  # içerisinde kesme işareti kullanacaksan çift tırnak kullan 
                                             # içerisinde de çift tırnak kullanacaksan dıştakileri üçlü kullan
                                             # tırnakları üçlü kullanmak hata payını ortadan kaldırır
# Out:
#  "neredesin?" "erzurum'dayım"

# %%
print(4+1)
print("4+1")  #sayıları tırnak içine alırsan string olarak alır. almazsan sayı (integer) olaran alır
# Out:
# 5
# 4+1

# %%
print(3.14)  # ondalık sayılarda hep nokta kullanılır
print(3,14)  # virgül kullanırsan iki farklı değer olarak algılar
# Out:
# 3.14
# 3 14

# %%
print('first line')
print()
print('''third line''')  # içi boş ya da sadece "" yaparsan boş satır çıkarır
# Out:
# first line
#
# third line

# %%
print("pep8 kurallarına göre bir satırda 79dan fazla karakter kullanılmaz\
bu yüzden ters slash kullanarak aşağı inebilirsin")
# Out:
# pep8 kurallarına göre bir satırda 79dan fazla karakter kullanılmazbu yüzden ters slash kullanarak aşağı inebilirsin

# %%
print("ali, (yağmur), yağdı")  #parantezlerden, hemen önce ve sonra virgüllerden falan önce boşluğa gerek yok
# Out:
# ali, (yağmur), yağdı

# %%
print(" =, +=, ==, <, >, >=, in, not in, is, and, or, not")
# bunlar python opeatörleri, bunlardan hem önce hem de sonra bir boşluk bırakıyoruz
# Out:
#  =, +=, ==, <, >, >=, in, not in, is, and, or, not

# %%
print("comment satırı'nı tanıyalım")  # comment budur
                         # commentten önce iki, sonra da bir boşluk bıraksan iyi olur
# satır başında boşluğa gerek yoktur
# Out:
# comment satırı'nı tanıyalım

# %%
print("variables = value")  #değişkenlere değer atamak için "boşluk eşittir boşluk"
# Out:
# variables = value

# %%
print("devamı diğer derste")
# Out:
# devamı diğer derste
